# %%
import sys 
from pathlib import Path

# %%
root_dir = Path.cwd().parent
sys.path.append(str(root_dir))

# %%
from src.data_loader import load_data
from src.eda_utils import overview_dataset, separate_columns, analyze_univariate, hist_plot

# %%
dataset_name = [
    "delay_4_6_CONDITION_PRODUCT_SUPPLIER", 
    "delay_7_9_CONDITION_PRODUCT_SUPPLIER", 
    "not_delay_4_6_CONDITION_PRODUCT_SUPPLIER", 
    "not_delay_7_9_CONDITION_PRODUCT_SUPPLIER"
]

# %%
df = load_data("delay_7_9_CONDITION_PRODUCT_SUPPLIER")

# %%
df.dtypes
# Out:
# Order date                          object
# SUBSIDIARY_CD                       object
# GLOBAL_NO                           object
# CLASSIFY_CD                          int64
# CUST_CD                              int64
# BRAND_CD                            object
# INNER_CD                            object
# SUPPLIER_CD                         object
# Sales order line number              int64
# Stock class                          int64
# Consider count hodiday Saturday      int64
# SO QTY                               int64
# OTHER AREA SHIP DIV                float64
# ALLOCATION QTY                       int64
# SUPPLIER INV AMOUNT                float64
# PACKING RANK                        object
# PRODUCT_CD                          object
# PRODUCT ATTRIBUTION                  int64
# SPECIAL DIV                          int64
# LOGICAL PLANT                        int64
# PURCHASE AMOUNT                    float64
# VSD                                 object
# DIRECT SHIP FLG                      int64
# DELI_DIV                            object
# label                                int64
# Ship Mode                           object
# SHIP DECISION NO                   float64
# PACK QTY                             int64
# WEIGHT PER PIECE                     int64
# SUPPLIER_DIV                       float64
# SPECIAL_DIV                          int64
# SO_DAY_OF_MONTH                      int64
# SO_DAY_OF_WEEK                       int64
# REASON_CD                          float64
# SOUF_RCV_NO                         object
# QTUF_RCV_NO                        float64
# SO_TIME                              int64
# dtype: object

# %%
overview_dataset(df, "delay_7_9_CONDITION_PRODUCT_SUPPLIER")
# Out:
# Overview of delay_7_9_CONDITION_PRODUCT_SUPPLIER:
# Dataset shape: (26217, 37)
# Number of columns: 37
# Number of rows: 26217

# %%
num_cols, cat_cols = separate_columns(df)

# %%
analyze_univariate(df)
# Out:
# ### Analyze Univariate
#                                    count       mean       std       min  \
# Sales order line number          26217.0     268.88   4414.92      1.00
# Stock class                      26217.0       0.99      0.10      0.00
# Consider count hodiday Saturday  26217.0       1.46      1.89      0.00
# SO QTY                           26217.0      13.37    107.75      1.00
# ALLOCATION QTY                   26217.0      13.37    107.75      1.00
# SUPPLIER INV AMOUNT              26217.0   15589.66  59893.20      1.96
# PRODUCT ATTRIBUTION              26217.0       0.99      0.10      0.00
# LOGICAL PLANT                    26217.0      53.14      1.14     52.00
# PURCHASE AMOUNT                  26217.0   15589.74  59893.19      2.00
# DIRECT SHIP FLG                  26217.0       0.59      0.49      0.00
# label                            26217.0       1.00      0.00      1.00
# PACK QTY                         26217.0      11.35    250.93      0.00
# WEIGHT PER PIECE                 26217.0    1685.98  11743.39      1.00
# SO_DAY_OF_MONTH                  26217.0      13.88      8.71      1.00
# SO_DAY_OF_WEEK                   26217.0       3.14      1.50      1.00
# SO_TIME                          26217.0  136852.63  32429.30  73000.00
#
#                                       25%       50%       75%        max  \
# Sales order line number               1.0       5.0      26.0    90007.0
# Stock class                           1.0       1.0       1.0        1.0
# Consider count hodiday Saturday       0.0       0.0       4.0        4.0
# SO QTY                                1.0       2.0       6.0    10000.0
# ALLOCATION QTY                        1.0       2.0       6.0    10000.0
# SUPPLIER INV AMOUNT                1240.0    3770.0   12240.0  4151130.0
# PRODUCT ATTRIBUTION                   1.0       1.0       1.0        1.0
# LOGICAL PLANT                        52.0      53.0      53.0       55.0
# PURCHASE AMOUNT                    1240.0    3770.0   12240.0  4151130.0
# DIRECT SHIP FLG                       0.0       1.0       1.0        1.0
# label                                 1.0       1.0       1.0        1.0
# PACK QTY                              0.0       0.0       0.0    10000.0
# WEIGHT PER PIECE                     50.0     306.0    1138.0  1300000.0
# SO_DAY_OF_MONTH                       6.0      13.0      21.0       31.0
# SO_DAY_OF_WEEK                        2.0       3.0       5.0        6.0
# SO_TIME                          111029.0  142900.0  163528.0   202841.0
#
#                                  skewness  kurtosis
# Sales order line number             20.18    407.20
# Stock class                         -9.45     87.34
# Consider count hodiday Saturday      0.58     -1.64
# SO QTY                              47.05   3372.42
# ALLOCATION QTY                      47.05   3372.42
# SUPPLIER INV AMOUNT                 31.28   1584.87
# PRODUCT ATTRIBUTION                 -9.45     87.34
# LOGICAL PLANT                        0.71     -0.92
# PURCHASE AMOUNT                     31.28   1584.87
# DIRECT SHIP FLG                     -0.36     -1.87
# label                                0.00      0.00
# PACK QTY                            34.89   1325.13
# WEIGHT PER PIECE                    64.44   6197.07
# SO_DAY_OF_MONTH                      0.24     -1.15
# SO_DAY_OF_WEEK                       0.10     -1.20
# SO_TIME                             -0.24     -1.01

# %%
df['BRAND_CD'].nunique()
# Out:
# 867

# %%
df['CLASSIFY_CD'].nunique()
# Out:
# 1874

# %%
df["GLOBAL_NO"].nunique()
# Out:
# 26217

# %%
df["SPECIAL DIV"].nunique()
# Out:
# 2

# %%
hist_plot(df, num_cols)
